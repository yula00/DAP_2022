# %% [markdown]
# <a href="https://colab.research.google.com/github/yula00/DAP_2022/blob/main/%5BDAP_2022%5D_Finalterm_Lab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Final Term Examination - Lab Session
# ### Data Analysis Programming - 4471017
# ##### Kangwon National University
# ##### 28. Oct. 2022.
# ---
# | Problem | Score |
# |---------|-------|
# | 1       |(&emsp;&emsp;) / 10    |
# | 2       |(&emsp;&emsp;) / 10    |
# | 2       |(&emsp;&emsp;) / 30    |
# | Total   |(&emsp;&emsp;) / 50    |
#
# ---
# * This examination contains **two problems**.
#
# * You have **40 minutes** to complete the examination.
#
# * Please download `.ipynb` file and submit it on ERUI.
#
# * No need to consider colors.
# ---

# %% [markdown]
# # Load Packages

# %%
# %matplotlib inline
 
import matplotlib.pyplot as plt
import numpy as np
import os
import pprint
pp = pprint.PrettyPrinter(indent=4)

# %% [markdown]
# # Problem. Classification
#
# 동물 얼굴 사진을 이용하여 동물종을 분류하는 모델을 구축하려 한다.

# %% [markdown]
# ## Load Dataset
# 데이터 로드와 관련된 부분.
# 본 부분은 따로 수정하실 필요 없습니다.

# %%
# !wget https://vcla.stat.ucla.edu/people/zhangzhang-si/HiT/AnimalFace.zip
# Out:
# --2022-12-15 16:52:33--  https://vcla.stat.ucla.edu/people/zhangzhang-si/HiT/AnimalFace.zip
# Resolving vcla.stat.ucla.edu (vcla.stat.ucla.edu)... 128.199.9.172
# Connecting to vcla.stat.ucla.edu (vcla.stat.ucla.edu)|128.199.9.172|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 37324985 (36M) [application/zip]
# Saving to: ‘AnimalFace.zip’
#
# AnimalFace.zip      100%[===================>]  35.60M  96.2MB/s    in 0.4s
#
# 2022-12-15 16:52:34 (96.2 MB/s) - ‘AnimalFace.zip’ saved [37324985/37324985]

# %%
# !unzip AnimalFace.zip
# Out:
# Archive:  AnimalFace.zip
#   inflating: Image/DuckHead/duckside0053.jpg
#   inflating: Image/DuckHead/duckside0072.jpg
#   inflating: Image/DuckHead/duckside0087.jpg
#   inflating: Image/DuckHead/duckside0088.jpg
#   inflating: Image/DuckHead/duckside0051.jpg
#   inflating: Image/DuckHead/duck-02.jpg
#   inflating: Image/DuckHead/duckside0075.jpg
#   inflating: Image/DuckHead/Knobbilled Duck 268010.jpg
#   inflating: Image/DuckHead/duckside0096.jpg
#   inflating: Image/DuckHead/duckside0074.jpg
#   inflating: Image/DuckHead/duckside0100.jpg
#   inflating: Image/DuckHead/duckside0011.jpg
#   inflating: Image/DuckHead/duckside0013.jpg
#   inflating: Image/DuckHead/duckside0045.jpg
#   inflating: Image/DuckHead/duckside0030.jpg
#   inflating: Image/DuckHead/duckside0077.jpg
#   inflating: Image/DuckHead/duckside0067.jpg
#   inflating: Image/DuckHead/duckside0014.jpg
#   inflating: Image/DuckHead/duckside0063.jpg
#   inflating: Image/DuckHead/duckside0049.jpg
#   inflating: Image/DuckHead/duckside0064.jpg
#   inflating: Image/DuckHead/Duck.jpg
#   inflating: Image/DuckHead/duckside0097.jpg
#   inflating: Image/DuckHead/duckside0034.jpg
#   inflating: Image/DuckHead/duckside0006.jpg
#   inflating: Image/DuckHead/Duck_head.JPG
#   inflating: Image/DuckHead/duckside0020.jpg
#   inflating: Image/DuckHead/LongTailedDuck2.jpg
#   inflating: Image/DuckHead/duckside0004.jpg
#   inflating: Image/DuckHead/duckside0070.jpg
#   inflating: Image/DuckHead/duckside0098.jpg
#   inflating: Image/DuckHead/01_08_18---Duck_web.jpg
#   inflating: Image/DuckHead/Yellowbilled Duck 268012.jpg
#   inflating: Image/DuckHead/duckside0032.jpg
#   inflating: Image/DuckHead/duckside0091.jpg
#   inflating: Image/DuckHead/duckside0084.jpg
#   inflating: Image/DuckHead/duckside0018.jpg
#   inflating: Image/DuckHead/duckside0017.jpg
#   inflating: Image/DuckHead/duckside0080.jpg
#   inflating: Image/DuckHead/fulvous_whistling_duck-2.jpg
#   inflating: Image/DuckHead/duckside0031.jpg
#   inflating: Image/DuckHead/duckside0089.jpg
#   inflating: Image/DuckHead/duckside0012.jpg
#   inflating: Image/DuckHead/duckside0016.jpg
#   inflating: Image/DuckHead/duckside0009.jpg
#   inflating: Image/DuckHead/duckside0010.jpg
#   inflating: Image/DuckHead/duckside0090.jpg
#   inflating: Image/DuckHead/duckside0015.jpg
#   inflating: Image/DuckHead/duckside0095.jpg
#   inflating: Image/DuckHead/duckside0029.jpg
#   inflating: Image/DuckHead/duckside0085.jpg
#   inflating: Image/DuckHead/duckside0069.jpg
#   inflating: Image/DuckHead/duckside0035.jpg
#   inflating: Image/DuckHead/duckside0021.jpg
#   inflating: Image/DuckHead/duckside0040.jpg
#   inflating: Image/DuckHead/duck5.jpg
#   inflating: Image/DuckHead/ducks2.jpg
#   inflating: Image/DuckHead/duckside0061.jpg
#   inflating: Image/DuckHead/duckside0062.jpg
#   inflating: Image/DuckHead/duckside0037.jpg
#   inflating: Image/DuckHead/duckside0047.jpg
#   inflating: Image/DuckHead/duckside0073.jpg
#   inflating: Image/DuckHead/ducks3.jpg
#   inflating: Image/DuckHead/duckside0066.jpg
#   inflating: Image/DuckHead/duckside0092.jpg
#   inflating: Image/DuckHead/duckside0081.jpg
#   inflating: Image/DuckHead/duckside0058.jpg
#   inflating: Image/DuckHead/duckside0019.jpg
#   inflating: Image/DuckHead/duckside0046.jpg
#   inflating: Image/DuckHead/duckside0025.jpg
#   inflating: Image/DuckHead/duckside0036.jpg
#   inflating: Image/DuckHead/duckside0038.jpg
#   inflating: Image/DuckHead/duckside0048.jpg
#   inflating: Image/DuckHead/duckside0078.jpg
#   inflating: Image/DuckHead/duckside0099.jpg
#   inflating: Image/DuckHead/duckside0059.jpg
#   inflating: Image/DuckHead/duckside0041.jpg
#   inflating: Image/DuckHead/duckside0050.jpg
#   inflating: Image/DuckHead/duckside0042.jpg
#   inflating: Image/DuckHead/duckside0071.jpg
#   inflating: Image/DuckHead/duckside0001.jpg
#   inflating: Image/DuckHead/LongTailedDuck.jpg
#   inflating: Image/DuckHead/duckside0003.jpg
#   inflating: Image/DuckHead/duckside0052.jpg
#   inflating: Image/DuckHead/fulvous-whistling-duck.jpg
#   inflating: Image/DuckHead/duckside0054.jpg
#   inflating: Image/DuckHead/duckside0060.jpg
#   inflating: Image/DuckHead/duckside0057.jpg
#   inflating: Image/DuckHead/duckside0044.jpg
#   inflating: Image/DuckHead/duckside0083.jpg
#   inflating: Image/DuckHead/duckside0033.jpg
#   inflating: Image/DuckHead/duckside0005.jpg
#   inflating: Image/DuckHead/ducks1.jpg
#   inflating: Image/DuckHead/duckside0076.jpg
#   inflating: Image/DuckHead/duckside0093.jpg
#   inflating: Image/DuckHead/duckside0026.jpg
#   inflating: Image/DuckHead/duckside0002.jpg
#   inflating: Image/DuckHead/duckside0039.jpg
#   inflating: Image/DuckHead/duckside0043.jpg
#   inflating: Image/DuckHead/duckside0056.jpg
#   inflating: Image/DuckHead/duckside0055.jpg
#   inflating: Image/DuckHead/duckside0024.jpg
#   inflating: Image/DuckHead/duckside0094.jpg
#   inflating: Image/RabbitHead/rabbitfrontalfrontal0019.jpg
#   inflating: Image/RabbitHead/rabbitfrontalfrontal0036.jpg
#   inflating: Image/RabbitHead/rabbitfrontalfrontal0049.jpg
#   inflating: Image/RabbitHead/rabbitfrontalfrontal0031.jpg
#   inflating: Image/RabbitHead/rabbitfrontalfrontal0039.jpg
#   inflating: Image/RabbitHead/rabbitfrontalfrontal0048.jpg
#   inflating: Image/RabbitHead/rabbitfrontalfrontal0075.jpg
#   inflating: Image/RabbitHead/rabbitfrontalfrontal0094.jpg
#   inflating: Image/RabbitHead/rabbitfrontalfrontal0076.jpg
#   inflating: Image/RabbitHead/rabbitfrontalfrontal0086.jpg
#   inflating: Image/RabbitHead/rabbitfrontalfrontal0053.jpg
#   inflating: Image/RabbitHead/rabbitfrontalfrontal0034.jpg
#   inflating: Image/RabbitHead/rabbitfrontalfrontal0078.jpg
#   inflating: Image/RabbitHead/rabbitfrontalfrontal0062.jpg
#   inflating: Image/RabbitHead/rabbitfrontalfrontal0098.jpg
#   inflating: Image/RabbitHead/rabbitfrontalfrontal0023.jpg
#   inflating: Image/RabbitHead/rabbitfrontalfrontal0009.jpg
#   inflating: Image/RabbitHead/rabbitfrontalfrontal0100.jpg
#   inflating: Image/RabbitHead/rabbitfrontalfrontal0082.jpg
#   inflating: Image/RabbitHead/rabbitfrontalfrontal0065.jpg
#   inflating: Image/RabbitHead/rabbitfrontalfrontal0067.jpg
#   inflating: Image/RabbitHead/rabbitfrontalfrontal0043.jpg
#   inflating: Image/RabbitHead/rabbitfrontalfrontal0004.jpg
#   inflating: Image/RabbitHead/rabbitfrontalfrontal0070.jpg
#   inflating: Image/RabbitHead/rabbitfrontalfrontal0040.jpg
#   inflating: Image/RabbitHead/rabbitfrontalfrontal0018.jpg
#   inflating: Image/RabbitHead/rabbitfrontalfrontal0073.jpg
#   inflating: Image/RabbitHead/rabbitfrontalfrontal0069.jpg
#   inflating: Image/RabbitHead/rabbitfrontalfrontal0030.jpg
#   inflating: Image/RabbitHead/rabbitfrontalfrontal0047.jpg
#   inflating: Image/RabbitHead/rabbitfrontalfrontal0052.jpg
#   inflating: Image/RabbitHead/rabbitfrontalfrontal0055.jpg
#   inflating: Image/RabbitHead/rabbitfrontalfrontal0025.jpg
#   inflating: Image/RabbitHead/rabbitfrontalfrontal0022.jpg
#   inflating: Image/RabbitHead/rabbitfrontalfrontal0079.jpg
#   inflating: Image/RabbitHead/rabbitfrontalfrontal0090.jpg
#   inflating: Image/RabbitHead/rabbitfrontalfrontal0035.jpg
#   inflating: Image/RabbitHead/rabbitfrontalfrontal0046.jpg
#   inflating: Image/RabbitHead/rabbitfrontalfrontal0061.jpg
#   inflating: Image/RabbitHead/rabbitfrontalfrontal0099.jpg
#   inflating: Image/RabbitHead/rabbitfrontalfrontal0093.jpg
#   inflating: Image/RabbitHead/rabbitfrontalfrontal0038.jpg
#   inflating: Image/RabbitHead/rabbitfrontalfrontal0005.jpg
#   inflating: Image/RabbitHead/rabbitfrontalfrontal0089.jpg
#   inflating: Image/RabbitHead/rabbitfrontalfrontal0058.jpg
#   inflating: Image/RabbitHead/rabbitfrontalfrontal0054.jpg
#   inflating: Image/RabbitHead/rabbitfrontalfrontal0085.jpg
#   inflating: Image/RabbitHead/rabbitfrontalfrontal0042.jpg
#   inflating: Image/RabbitHead/rabbitfrontalfrontal0029.jpg
#   inflating: Image/RabbitHead/rabbitfrontalfrontal0051.jpg
#   inflating: Image/RabbitHead/rabbitfrontalfrontal0060.jpg
#   inflating: Image/RabbitHead/rabbitfrontalfrontal0011.jpg
#   inflating: Image/RabbitHead/rabbitfrontalfrontal0006.jpg
#   inflating: Image/RabbitHead/rabbitfrontalfrontal0064.jpg
#   inflating: Image/RabbitHead/rabbitfrontalfrontal0014.jpg
#   inflating: Image/RabbitHead/rabbitfrontalfrontal0050.jpg
#   inflating: Image/RabbitHead/rabbitfrontalfrontal0097.jpg
#   inflating: Image/RabbitHead/rabbitfrontalfrontal0024.jpg
#   inflating: Image/RabbitHead/rabbitfrontalfrontal0056.jpg
#   inflating: Image/RabbitHead/rabbitfrontalfrontal0001.jpg
#   inflating: Image/RabbitHead/rabbitfrontalfrontal0071.jpg
#   inflating: Image/RabbitHead/rabbitfrontalfrontal0012.jpg
#   inflating: Image/RabbitHead/rabbitfrontalfrontal0087.jpg
#   inflating: Image/RabbitHead/rabbitfrontalfrontal0084.jpg
#   inflating: Image/RabbitHead/rabbitfrontalfrontal0003.jpg
#   inflating: Image/RabbitHead/rabbitfrontalfrontal0063.jpg
#   inflating: Image/RabbitHead/rabbitfrontalfrontal0028.jpg
#   inflating: Image/RabbitHead/rabbitfrontalfrontal0033.jpg
#   inflating: Image/RabbitHead/rabbitfrontalfrontal0007.jpg
#   inflating: Image/RabbitHead/rabbitfrontalfrontal0096.jpg
#   inflating: Image/RabbitHead/rabbitfrontalfrontal0092.jpg
#   inflating: Image/RabbitHead/rabbitfrontalfrontal0013.jpg
#   inflating: Image/RabbitHead/rabbitfrontalfrontal0041.jpg
#   inflating: Image/RabbitHead/rabbitfrontalfrontal0066.jpg
#   inflating: Image/RabbitHead/rabbitfrontalfrontal0010.jpg
#   inflating: Image/RabbitHead/rabbitfrontalfrontal0026.jpg
#   inflating: Image/RabbitHead/rabbitfrontalfrontal0080.jpg
#   inflating: Image/RabbitHead/rabbitfrontalfrontal0002.jpg
#   inflating: Image/RabbitHead/rabbitfrontalfrontal0074.jpg
#   inflating: Image/RabbitHead/rabbitfrontalfrontal0016.jpg
#   inflating: Image/RabbitHead/rabbitfrontalfrontal0072.jpg
#   inflating: Image/RabbitHead/rabbitfrontalfrontal0037.jpg
#   inflating: Image/RabbitHead/rabbitfrontalfrontal0021.jpg
#   inflating: Image/RabbitHead/rabbitfrontalfrontal0032.jpg
#   inflating: Image/RabbitHead/rabbitfrontalfrontal0020.jpg
#   inflating: Image/RabbitHead/rabbitfrontalfrontal0027.jpg
#   inflating: Image/RabbitHead/rabbitfrontalfrontal0088.jpg
#   inflating: Image/RabbitHead/rabbitfrontalfrontal0015.jpg
#   inflating: Image/RabbitHead/rabbitfrontalfrontal0077.jpg
#   inflating: Image/RabbitHead/rabbitfrontalfrontal0044.jpg
#   inflating: Image/RabbitHead/rabbitfrontalfrontal0045.jpg
#   inflating: Image/RabbitHead/rabbitfrontalfrontal0081.jpg
#   inflating: Image/RabbitHead/rabbitfrontalfrontal0091.jpg
#   inflating: Image/RabbitHead/rabbitfrontalfrontal0008.jpg
#   inflating: Image/RabbitHead/rabbitfrontalfrontal0083.jpg
#   inflating: Image/RabbitHead/rabbitfrontalfrontal0095.jpg
#   inflating: Image/RabbitHead/rabbitfrontalfrontal0068.jpg
#   inflating: Image/RabbitHead/rabbitfrontalfrontal0057.jpg
#   inflating: Image/RabbitHead/rabbitfrontalfrontal0059.jpg
#   inflating: Image/RabbitHead/rabbitfrontalfrontal0017.jpg
#   inflating: Image/PigHead/pigfrontal0035.jpg
#   inflating: Image/PigHead/pigfrontal0043.jpg
#   inflating: Image/PigHead/pigfrontal0079.jpg
#   inflating: Image/PigHead/pigfrontal0033.jpg
#   inflating: Image/PigHead/pigfrontal0014.jpg
#   inflating: Image/PigHead/gtotem_pig.jpg
#   inflating: Image/PigHead/pigfrontal0068.jpg
#   inflating: Image/PigHead/pigfrontal0047.jpg
#   inflating: Image/PigHead/pigfrontal0005.jpg
#   inflating: Image/PigHead/pigfrontal0049.jpg
#   inflating: Image/PigHead/pigfrontal0034.jpg
#   inflating: Image/PigHead/pigfrontal0089.jpg
#   inflating: Image/PigHead/pigfrontal0018.jpg
#   inflating: Image/PigHead/pigfrontal0080.jpg
#   inflating: Image/PigHead/retarded-pig.jpg
#   inflating: Image/PigHead/pigfrontal0058.jpg
#   inflating: Image/PigHead/pigfrontal0100.jpg
#   inflating: Image/PigHead/pigfrontal0088.jpg
#   inflating: Image/PigHead/pigfrontal0010.jpg
#   inflating: Image/PigHead/pigfrontal0032.jpg
#   inflating: Image/PigHead/pigs3.jpg
#   inflating: Image/PigHead/pigfrontal0090.jpg
#   inflating: Image/PigHead/pigfrontal0087.jpg
#   inflating: Image/PigHead/pigfrontal0042.jpg
#   inflating: Image/PigHead/pigfrontal0066.jpg
#   inflating: Image/PigHead/pigfrontal0050.jpg
#   inflating: Image/PigHead/pigfrontal0099.jpg
#   inflating: Image/PigHead/pigfrontal0054.jpg
#   inflating: Image/PigHead/pigfrontal0082.jpg
#   inflating: Image/PigHead/pigfrontal0073.jpg
#   inflating: Image/PigHead/pigfrontal0006.jpg
#   inflating: Image/PigHead/pigfrontal0020.jpg
#   inflating: Image/PigHead/pigfrontal0059.jpg
#   inflating: Image/PigHead/pigfrontal0031.jpg
#   inflating: Image/PigHead/pigfrontal0040.jpg
#   inflating: Image/PigHead/pigfrontal0075.jpg
#   inflating: Image/PigHead/pigfrontal0037.jpg
#   inflating: Image/PigHead/pigfrontal0046.jpg
#   inflating: Image/PigHead/pigfrontal0019.jpg
#   inflating: Image/PigHead/pigfrontal0074.jpg
#   inflating: Image/PigHead/pigfrontal0012.jpg
#   inflating: Image/PigHead/pigfrontal0011.jpg
#   inflating: Image/PigHead/pigfrontal0039.jpg
#   inflating: Image/PigHead/cute-pig1.jpg
#   inflating: Image/PigHead/pigfrontal0041.jpg
#   inflating: Image/PigHead/187980686_f95619cc5b.jpg
#   inflating: Image/PigHead/pigfrontal0096.jpg
#   inflating: Image/PigHead/cute-pig3.jpg
#   inflating: Image/PigHead/pigfrontal0076.jpg
#   inflating: Image/PigHead/pigfrontal0067.jpg
#   inflating: Image/PigHead/pigfrontal0044.jpg
#   inflating: Image/PigHead/pigfrontal0013.jpg
#   inflating: Image/PigHead/pigfrontal0026.jpg
#   inflating: Image/PigHead/pigfrontal0077.jpg
#   inflating: Image/PigHead/pigfrontal0053.jpg
#   inflating: Image/PigHead/cute-pig2.jpg
#   inflating: Image/PigHead/pigfrontal0065.jpg
#   inflating: Image/PigHead/pigfrontal0015.jpg
#   inflating: Image/PigHead/pigfrontal0092.jpg
#   inflating: Image/PigHead/pigfrontal0060.jpg
#   inflating: Image/PigHead/pigfrontal0045.jpg
#   inflating: Image/PigHead/pigfrontal0016.jpg
#   inflating: Image/PigHead/pigfrontal0056.jpg
#   inflating: Image/PigHead/pigfrontal0052.jpg
#   inflating: Image/PigHead/pigfrontal0003.jpg
#   inflating: Image/PigHead/pigfrontal0084.jpg
#   inflating: Image/PigHead/pigs.jpg
#   inflating: Image/PigHead/pigfrontal0036.jpg
#   inflating: Image/PigHead/pigfrontal0083.jpg
#   inflating: Image/PigHead/pigfrontal0071.jpg
#   inflating: Image/PigHead/pigfrontal0017.jpg
#   inflating: Image/PigHead/cute-pig.jpg
#   inflating: Image/PigHead/pigfrontal0086.jpg
#   inflating: Image/PigHead/pigfrontal0093.jpg
#   inflating: Image/PigHead/s_pig.jpg
#   inflating: Image/PigHead/pigfrontal0048.jpg
#   inflating: Image/PigHead/pigfrontal0097.jpg
#   inflating: Image/PigHead/pigfrontal0078.jpg
#   inflating: Image/PigHead/pigfrontal0029.jpg
#   inflating: Image/PigHead/babe8.jpg
#   inflating: Image/PigHead/pigfrontal0091.jpg
#   inflating: Image/PigHead/pigfrontal0095.jpg
#   inflating: Image/PigHead/pigfrontal0070.jpg
#   inflating: Image/PigHead/pigfrontal0081.jpg
#   inflating: Image/PigHead/pigfrontal0062.jpg
#   inflating: Image/PigHead/pigfrontal0030.jpg
#   inflating: Image/PigHead/pigs4.jpg
#   inflating: Image/PigHead/pigfrontal0021.jpg
#   inflating: Image/PigHead/pigfrontal0061.jpg
#   inflating: Image/PigHead/pigfrontal0009.jpg
#   inflating: Image/PigHead/pigfrontal0002.jpg
#   inflating: Image/PigHead/4564271765_37192fe72f.jpg
#   inflating: Image/PigHead/pigfrontal0085.jpg
#   inflating: Image/PigHead/pigfrontal0024.jpg
#   inflating: Image/PigHead/pigfrontal0051.jpg
#   inflating: Image/PigHead/pigfrontal0022.jpg
#   inflating: Image/PigHead/pigfrontal0057.jpg
#   inflating: Image/PigHead/pigfrontal0025.jpg
#   inflating: Image/PigHead/pigfrontal0094.jpg
#   inflating: Image/PigHead/pigfrontal0098.jpg
#   inflating: Image/PigHead/pigfrontal0023.jpg
#   inflating: Image/PandaHead/Shy_panda-150x112.jpg
#   inflating: Image/PandaHead/panda-bear-d.jpg
#   inflating: Image/PandaHead/panda016.jpg
#   inflating: Image/PandaHead/pandafrontal0016.jpg
#   inflating: Image/PandaHead/panda (1).jpg
#   inflating: Image/PandaHead/giant-panda (2).jpg
#   inflating: Image/PandaHead/Pandas_drinking3.jpg
#   inflating: Image/PandaHead/4562404531_63f12018e0.jpg
#   inflating: Image/PandaHead/Pandas_drinking4.jpg
#   inflating: Image/PandaHead/giant_panda_300_318.jpg
#   inflating: Image/PandaHead/4562397977_1c1ba77716.jpg
#   inflating: Image/PandaHead/pandafrontal0008.jpg
#   inflating: Image/PandaHead/Giant Panda.jpg
#   inflating: Image/PandaHead/pandafrontal0011.jpg
#   inflating: Image/PandaHead/panda-on-slide.jpg
#   inflating: Image/PandaHead/vo.dc.panda.snow.cnn.640x360.jpg
#   inflating: Image/PandaHead/giant_panda-thumb-640xauto-10489.jpg
#   inflating: Image/PandaHead/giant-panda10.jpg
#   inflating: Image/PandaHead/4563027230_3dc9fda675.jpg
#   inflating: Image/PandaHead/pandafrontal0009.jpg
#   inflating: Image/PandaHead/panda012.jpg
#   inflating: Image/PandaHead/Panda4_2jpg
#   inflating: Image/PandaHead/panda DSC01742.JPG
#   inflating: Image/PandaHead/4563017548_d56748755e.jpg
#   inflating: Image/PandaHead/baby-panda.jpg
#   inflating: Image/PandaHead/giant-panda13.jpg
#   inflating: Image/PandaHead/panda001.jpg
#   inflating: Image/PandaHead/pandafrontal0012.jpg
#   inflating: Image/PandaHead/panda-1.jpg
#   inflating: Image/PandaHead/DSC01759.jpg
#   inflating: Image/PandaHead/pandafrontal0002.jpg
#   inflating: Image/PandaHead/pandagi.jpg
#   inflating: Image/PandaHead/pandafrontal0033.jpg
#   inflating: Image/PandaHead/pandafrontal0022.jpg
#   inflating: Image/PandaHead/pandafrontal0026.jpg
#   inflating: Image/PandaHead/giant-panda (1).jpg
#   inflating: Image/PandaHead/giant-panda15.jpg
#   inflating: Image/PandaHead/panda_jingjing_image2-660x440.jpg
#   inflating: Image/PandaHead/DSC01812.jpg
#   inflating: Image/PandaHead/4563030924_97d4312cba.jpg
#   inflating: Image/PandaHead/giant-panda01.jpg
#   inflating: Image/PandaHead/4562385399_98b9bba1ab.jpg
#   inflating: Image/PandaHead/pandafrontal0001.jpg
#   inflating: Image/PandaHead/pandafrontal0020.jpg
#   inflating: Image/PandaHead/4563014956_529815871f.jpg
#   inflating: Image/PandaHead/mid-Chengdu-oso-panda-comiendo-v01-mpg.ogg.jpg
#   inflating: Image/PandaHead/pandafrontal0014.jpg
#   inflating: Image/PandaHead/panda0106.jpg
#   inflating: Image/PandaHead/Panda7.jpg
#   inflating: Image/PandaHead/giant-panda11.jpg
#   inflating: Image/PandaHead/Panda (3).jpg
#   inflating: Image/PandaHead/4563030722_49a404990f.jpg
#   inflating: Image/PandaHead/pandafrontal0006.jpg
#   inflating: Image/PandaHead/DSC01813.jpg
#   inflating: Image/PandaHead/Panda4.jpg
#   inflating: Image/PandaHead/pandafrontal0023.jpg
#   inflating: Image/PandaHead/4562387141_249c388e6e.jpg
#   inflating: Image/PandaHead/20080310_panda.jpg
#   inflating: Image/PandaHead/pandafrontal0007.jpg
#   inflating: Image/PandaHead/pandafrontal0028.jpg
#   inflating: Image/PandaHead/giant-panda02.jpg
#   inflating: Image/PandaHead/4563017774_c899ef6f0f.jpg
#   inflating: Image/PandaHead/panda_jingjing_image1.jpg
#   inflating: Image/PandaHead/giant-panda.jpg
#   inflating: Image/PandaHead/DSC01798.jpg
#   inflating: Image/PandaHead/29tlab_panda.480.jpg
#   inflating: Image/PandaHead/pandafrontal0010.jpg
#   inflating: Image/PandaHead/Pandas_drinking.jpg
#   inflating: Image/PandaHead/pandafrontal0021.jpg
#   inflating: Image/PandaHead/giant-panda-picture.jpg
#   inflating: Image/PandaHead/4563033998_c985ac0418.jpg
#   inflating: Image/PandaHead/4562382757_b6296c3351.jpg
#   inflating: Image/PandaHead/pandafrontal0032.jpg
#   inflating: Image/PandaHead/panda-mom-cub-lg.jpg
#   inflating: Image/PandaHead/pandafrontal0027.jpg
#   inflating: Image/PandaHead/4562730849_07d327d517.jpg
#   inflating: Image/PandaHead/pandafrontal0031.jpg
#   inflating: Image/PandaHead/giant-panda08.jpg
#   inflating: Image/PandaHead/pandas.jpg
#   inflating: Image/PandaHead/Giant-panda1C-David-Sheppar-8146.jpg
#   inflating: Image/PandaHead/panda011.jpg
#   inflating: Image/PandaHead/panda015.jpg
#   inflating: Image/PandaHead/pandafrontal0017.jpg
#   inflating: Image/PandaHead/4563026718_e31a1fdc66.jpg
#   inflating: Image/PandaHead/pandafrontal0024.jpg
#   inflating: Image/PandaHead/pandafrontal0019.jpg
#   inflating: Image/PandaHead/DSC01849.jpg
#   inflating: Image/PandaHead/panda0000000052.jpg
#   inflating: Image/PandaHead/DSC01811.jpg
#   inflating: Image/PandaHead/panda013.jpg
#   inflating: Image/PandaHead/DSC01879.jpg
#   inflating: Image/PandaHead/panda0014.jpg
#   inflating: Image/PandaHead/Panda_playing_a_ball-150x112.jpg
#   inflating: Image/PandaHead/panda009.jpg
#   inflating: Image/PandaHead/pandafrontal0025.jpg
#   inflating: Image/PandaHead/panda00000000051.jpg
#   inflating: Image/PandaHead/pandafrontal0003.jpg
#   inflating: Image/PandaHead/pandafrontal0029.jpg
#   inflating: Image/PandaHead/pandafrontal0013.jpg
#   inflating: Image/PandaHead/panda (2).jpg
#   inflating: Image/PandaHead/pandafrontal0005.jpg
#   inflating: Image/PandaHead/Pandas_drinking2.jpg
#   inflating: Image/PandaHead/500x333_Giant-Panda.jpg
#   inflating: Image/PandaHead/pandafrontal0004.jpg
#   inflating: Image/PandaHead/giant_panda_41506_233785.jpg
#   inflating: Image/PandaHead/pandas2.jpg
#   inflating: Image/PandaHead/giant-panda-cub-china_m.jpg
#   inflating: Image/PandaHead/4563032448_74a542f9fd.jpg
#   inflating: Image/PandaHead/panda sichuan trip photograph DSC01751.JPG
#   inflating: Image/PandaHead/4562385069_5fc85a4d25.jpg
#   inflating: Image/PandaHead/4563034386_eb6466d1bc.jpg
#   inflating: Image/PandaHead/panda.jpg
#   inflating: Image/PandaHead/pandafrontal0015.jpg
#   inflating: Image/PandaHead/pandafrontal0030.jpg
#   inflating: Image/PandaHead/4562384687_477a9fd447.jpg
#   inflating: Image/PandaHead/panda (4).jpg
#   inflating: Image/PandaHead/pandafrontal0018.jpg
#   inflating: Image/PandaHead/4563013112_67062bc46e.jpg
#   inflating: Image/PandaHead/baby_panda_in_a_crib-150x112.jpg
#   inflating: Image/ChickenHead/chickenside0058.jpg
#   inflating: Image/ChickenHead/chickenside0037.jpg
#   inflating: Image/ChickenHead/chickenside0065.jpg
#   inflating: Image/ChickenHead/chickenside0067.jpg
#   inflating: Image/ChickenHead/chickenside0098.jpg
#   inflating: Image/ChickenHead/chickenside0034.jpg
#   inflating: Image/ChickenHead/chickenside0094.jpg
#   inflating: Image/ChickenHead/chickenside0004.jpg
#   inflating: Image/ChickenHead/chickenside0033.jpg
#   inflating: Image/ChickenHead/chickenside0072.jpg
#   inflating: Image/ChickenHead/chickenside0023.jpg
#   inflating: Image/ChickenHead/chickenside0001.jpg
#   inflating: Image/ChickenHead/chickenside0025.jpg
#   inflating: Image/ChickenHead/chickenside0061.jpg
#   inflating: Image/ChickenHead/chickenside0007.jpg
#   inflating: Image/ChickenHead/chickenside0013.jpg
#   inflating: Image/ChickenHead/chickenside0053.jpg
#   inflating: Image/ChickenHead/chickenside0046.jpg
#   inflating: Image/ChickenHead/chickenside0026.jpg
#   inflating: Image/ChickenHead/chickenside0009.jpg
#   inflating: Image/ChickenHead/chickenside0084.jpg
#   inflating: Image/ChickenHead/chickenside0014.jpg
#   inflating: Image/ChickenHead/chickenside0038.jpg
#   inflating: Image/ChickenHead/chickenside0079.jpg
#   inflating: Image/ChickenHead/chickenside0090.jpg
#   inflating: Image/ChickenHead/chickenside0055.jpg
#   inflating: Image/ChickenHead/chickenside0016.jpg
#   inflating: Image/ChickenHead/chickenside0012.jpg
#   inflating: Image/ChickenHead/chickenside0047.jpg
#   inflating: Image/ChickenHead/chickenside0005.jpg
#   inflating: Image/ChickenHead/chickenside0048.jpg
#   inflating: Image/ChickenHead/chickenside0031.jpg
#   inflating: Image/ChickenHead/chickenside0006.jpg
#   inflating: Image/ChickenHead/chickenside0017.jpg
#   inflating: Image/ChickenHead/chickenside0095.jpg
#   inflating: Image/ChickenHead/chickenside0064.jpg
#   inflating: Image/ChickenHead/chickenside0041.jpg
#   inflating: Image/ChickenHead/chickenside0081.jpg
#   inflating: Image/ChickenHead/chickenside0062.jpg
#   inflating: Image/ChickenHead/chickenside0024.jpg
#   inflating: Image/ChickenHead/chickenside0039.jpg
#   inflating: Image/ChickenHead/chickenside0063.jpg
#   inflating: Image/ChickenHead/chickenside0087.jpg
#   inflating: Image/ChickenHead/chickenside0073.jpg
#   inflating: Image/ChickenHead/chickenside0085.jpg
#   inflating: Image/ChickenHead/chickenside0029.jpg
#   inflating: Image/ChickenHead/chickenside0086.jpg
#   inflating: Image/ChickenHead/chickenside0099.jpg
#   inflating: Image/ChickenHead/chickenside0097.jpg
#   inflating: Image/ChickenHead/chickenside0088.jpg
#   inflating: Image/ChickenHead/chickenside0035.jpg
#   inflating: Image/ChickenHead/chickenside0043.jpg
#   inflating: Image/ChickenHead/chickenside0078.jpg
#   inflating: Image/ChickenHead/chickenside0030.jpg
#   inflating: Image/ChickenHead/chickenside0089.jpg
#   inflating: Image/ChickenHead/chickenside0044.jpg
#   inflating: Image/ChickenHead/chickenside0045.jpg
#   inflating: Image/ChickenHead/chickenside0018.jpg
#   inflating: Image/ChickenHead/chickenside0042.jpg
#   inflating: Image/ChickenHead/chickenside0092.jpg
#   inflating: Image/ChickenHead/chickenside0052.jpg
#   inflating: Image/ChickenHead/chickenside0032.jpg
#   inflating: Image/ChickenHead/chickenside0002.jpg
#   inflating: Image/ChickenHead/chickenside0059.jpg
#   inflating: Image/ChickenHead/chickenside0075.jpg
#   inflating: Image/ChickenHead/chickenside0027.jpg
#   inflating: Image/ChickenHead/chickenside0049.jpg
#   inflating: Image/ChickenHead/chickenside0100.jpg
#   inflating: Image/ChickenHead/chickenside0076.jpg
#   inflating: Image/ChickenHead/chickenside0070.jpg
#   inflating: Image/ChickenHead/chickenside0091.jpg
#   inflating: Image/ChickenHead/chickenside0021.jpg
#   inflating: Image/ChickenHead/chickenside0054.jpg
#   inflating: Image/ChickenHead/chickenside0069.jpg
#   inflating: Image/ChickenHead/chickenside0019.jpg
#   inflating: Image/ChickenHead/chickenside0015.jpg
#   inflating: Image/ChickenHead/chickenside0008.jpg
#   inflating: Image/ChickenHead/chickenside0010.jpg
#   inflating: Image/ChickenHead/chickenside0057.jpg
#   inflating: Image/ChickenHead/chickenside0068.jpg
#   inflating: Image/ChickenHead/chickenside0028.jpg
#   inflating: Image/ChickenHead/chickenside0060.jpg
#   inflating: Image/ChickenHead/chickenside0003.jpg
#   inflating: Image/ChickenHead/chickenside0036.jpg
#   inflating: Image/ChickenHead/chickenside0050.jpg
#   inflating: Image/ChickenHead/chickenside0066.jpg
#   inflating: Image/ChickenHead/chickenside0083.jpg
#   inflating: Image/ChickenHead/chickenside0022.jpg
#   inflating: Image/ChickenHead/chickenside0071.jpg
#   inflating: Image/ChickenHead/chickenside0040.jpg
#   inflating: Image/ChickenHead/chickenside0074.jpg
#   inflating: Image/ChickenHead/chickenside0051.jpg
#   inflating: Image/ChickenHead/chickenside0056.jpg
#   inflating: Image/ChickenHead/chickenside0080.jpg
#   inflating: Image/ChickenHead/chickenside0020.jpg
#   inflating: Image/ChickenHead/chickenside0093.jpg
#   inflating: Image/ChickenHead/chickenside0077.jpg
#   inflating: Image/ChickenHead/chickenside0096.jpg
#   inflating: Image/ChickenHead/chickenside0011.jpg
#   inflating: Image/ChickenHead/chickenside0082.jpg
#   inflating: Image/LionHead/lion,tyr.jpg
#   inflating: Image/LionHead/lionjmty.jpg
#   inflating: Image/LionHead/lion,i87.jpg
#   inflating: Image/LionHead/lionl189@.jpg
#   inflating: Image/LionHead/lionl255@.jpg
#   inflating: Image/LionHead/lionlh100.JPG
#   inflating: Image/LionHead/lionlh47.jpg
#   inflating: Image/LionHead/lioni676.jpg
#   inflating: Image/LionHead/lionmtyt67.jpg
#   inflating: Image/LionHead/lion.l98.jpg
#   inflating: Image/LionHead/lionk6y76.jpg
#   inflating: Image/LionHead/lionlh97.jpg
#   inflating: Image/LionHead/lioni87.jpg
#   inflating: Image/LionHead/lion;oi.jpg
#   inflating: Image/LionHead/lionlh104.jpg
#   inflating: Image/LionHead/lionk877.jpg
#   inflating: Image/LionHead/lionk87.jpg
#   inflating: Image/LionHead/lionlh175.jpg
#   inflating: Image/LionHead/lionioi.jpg
#   inflating: Image/LionHead/lionlh01.jpg
#   inflating: Image/LionHead/lionkuyi.jpg
#   inflating: Image/LionHead/lionlh174.jpg
#   inflating: Image/LionHead/lionky.jpg
#   inflating: Image/LionHead/liongmjr.jpg
#   inflating: Image/LionHead/lion131.jpg
#   inflating: Image/LionHead/lionlh101.jpg
#   inflating: Image/LionHead/lionlh177.jpg
#   inflating: Image/LionHead/lion54546.jpg
#   inflating: Image/LionHead/lionl180@.jpg
#   inflating: Image/LionHead/lionmk675.jpg
#   inflating: Image/LionHead/lionlh78.jpg
#   inflating: Image/LionHead/lion,l87o99.jpg
#   inflating: Image/LionHead/lionl114@.jpg
#   inflating: Image/LionHead/lion[909.jpg
#   inflating: Image/LionHead/lionp;98p0.jpg
#   inflating: Image/LionHead/lionl206@.JPG
#   inflating: Image/LionHead/lionl203@.jpg
#   inflating: Image/LionHead/lionl258@.jpg
#   inflating: Image/LionHead/lionk767676.jpg
#   inflating: Image/LionHead/lionk 6.jpg
#   inflating: Image/LionHead/lionl200@.jpg
#   inflating: Image/LionHead/lionk8.jpg
#   inflating: Image/LionHead/lionl202@.jpg
#   inflating: Image/LionHead/lionl282@.JPG
#   inflating: Image/LionHead/lion20060925113100644.jpg
#   inflating: Image/LionHead/lionlh99.jpg
#   inflating: Image/LionHead/lionlh79.JPG
#   inflating: Image/LionHead/liongnyt5.jpg
#   inflating: Image/LionHead/lionl789.jpg
#   inflating: Image/LionHead/lionjry65.jpg
#   inflating: Image/LionHead/lionlh173.jpg
#   inflating: Image/LionHead/lionl157@.jpg
#   inflating: Image/LionHead/lionlh87.JPG
#   inflating: Image/LionHead/lionlu787.jpg
#   inflating: Image/LionHead/lionlh62.jpg
#   inflating: Image/LionHead/lion,7y.jpg
#   inflating: Image/LionHead/lionihtfhd.jpg
#   inflating: Image/LionHead/lionlh156.jpg
#   inflating: Image/LionHead/lionk766k.jpg
#   inflating: Image/LionHead/lion786.jpg
#   inflating: Image/LionHead/lionlh120.jpg
#   inflating: Image/LionHead/lionlh77.jpg
#   inflating: Image/LionHead/lionl118@.jpg
#   inflating: Image/LionHead/lionk7676.jpg
#   inflating: Image/LionHead/lionoi.jpg
#   inflating: Image/LionHead/lion54.jpg
#   inflating: Image/LionHead/lion78787.jpg
#   inflating: Image/LionHead/lionlh166.jpg
#   inflating: Image/LionHead/lionlh117.jpg
#   inflating: Image/LionHead/lionh4.jpg
#   inflating: Image/LionHead/lionlh145.jpg
#   inflating: Image/LionHead/lionl119@.jpg
#   inflating: Image/LionHead/lionlh132.jpg
#   inflating: Image/LionHead/lionmnt6y.jpg
#   inflating: Image/LionHead/lionk87oi.jpg
#   inflating: Image/LionHead/lionu76.jpg
#   inflating: Image/LionHead/lionshizi2_042.jpg
#   inflating: Image/LionHead/lionok78.jpg
#   inflating: Image/LionHead/lionhr57.jpg
#   inflating: Image/LionHead/lionl201@.jpg
#   inflating: Image/LionHead/lionl208@.jpg
#   inflating: Image/LionHead/lion78 7.jpg
#   inflating: Image/LionHead/lionjmyt7.jpg
#   inflating: Image/LionHead/lionlh162.jpg
#   inflating: Image/LionHead/lioni 8o.jpg
#   inflating: Image/LionHead/lion,ky7u6.jpg
#   inflating: Image/LionHead/lionlh45.jpg
#   inflating: Image/LionHead/lion7y686667.jpg
#   inflating: Image/LionHead/lionlh141.jpg
#   inflating: Image/LionHead/lionj 7.jpg
#   inflating: Image/LionHead/lionmk7y65.jpg
#   inflating: Image/LionHead/lion007.jpg
#   inflating: Image/LionHead/lion7676.jpg
#   inflating: Image/LionHead/lion,k 78.jpg
#   inflating: Image/LionHead/lionlh98.jpg
#   inflating: Image/LionHead/lionu67.jpg
#   inflating: Image/LionHead/lioni78.jpg
#   inflating: Image/LionHead/lioniuyi.jpg
#   inflating: Image/LionHead/liony45.jpg
#   inflating: Image/LionHead/lioni8777.jpg
#   inflating: Image/LionHead/lionl241@.jpg
#   inflating: Image/LionHead/lionl224@.jpg
#   inflating: Image/BearHead/bearfrontal0083.jpg
#   inflating: Image/BearHead/bearfrontal0023.jpg
#   inflating: Image/BearHead/bearfrontal0048.jpg
#   inflating: Image/BearHead/bearfrontal0041.jpg
#   inflating: Image/BearHead/bearfrontal0049.jpg
#   inflating: Image/BearHead/bearfrontal0065.jpg
#   inflating: Image/BearHead/bearfrontal0045.jpg
#   inflating: Image/BearHead/bearfrontal0053.jpg
#   inflating: Image/BearHead/bearfrontal0007.jpg
#   inflating: Image/BearHead/bearfrontal0089.jpg
#   inflating: Image/BearHead/bearfrontal0070.jpg
#   inflating: Image/BearHead/bearfrontal0046.jpg
#   inflating: Image/BearHead/bearfrontal0034.jpg
#   inflating: Image/BearHead/bearfrontal0050.jpg
#   inflating: Image/BearHead/bearfrontal0013.jpg
#   inflating: Image/BearHead/bearfrontal0097.jpg
#   inflating: Image/BearHead/bearfrontal0005.jpg
#   inflating: Image/BearHead/bearfrontal0066.jpg
#   inflating: Image/BearHead/bearfrontal0072.jpg
#   inflating: Image/BearHead/bearfrontal0073.jpg
#   inflating: Image/BearHead/bearfrontal0017.jpg
#   inflating: Image/BearHead/bearfrontal0036.jpg
#   inflating: Image/BearHead/bearfrontal0082.jpg
#   inflating: Image/BearHead/bearfrontal0010.jpg
#   inflating: Image/BearHead/bearfrontal0059.jpg
#   inflating: Image/BearHead/bearfrontal0030.jpg
#   inflating: Image/BearHead/black-bear.jpg
#   inflating: Image/BearHead/bearfrontal0079.jpg
#   inflating: Image/BearHead/bearfrontal0084.jpg
#   inflating: Image/BearHead/bearfrontal0008.jpg
#   inflating: Image/BearHead/bearfrontal0078.jpg
#   inflating: Image/BearHead/bearfrontal0027.jpg
#   inflating: Image/BearHead/bearfrontal0087.jpg
#   inflating: Image/BearHead/bearfrontal0042.jpg
#   inflating: Image/BearHead/bearfrontal0025.jpg
#   inflating: Image/BearHead/bearfrontal0016.jpg
#   inflating: Image/BearHead/bearfrontal0081.jpg
#   inflating: Image/BearHead/bearfrontal0032.jpg
#   inflating: Image/BearHead/bearfrontal0074.jpg
#   inflating: Image/BearHead/bearfrontal0063.jpg
#   inflating: Image/BearHead/bearfrontal0018.jpg
#   inflating: Image/BearHead/bearfrontal0085.jpg
#   inflating: Image/BearHead/bearfrontal0099.jpg
#   inflating: Image/BearHead/bearfrontal0080.jpg
#   inflating: Image/BearHead/bearfrontal0077.jpg
#   inflating: Image/BearHead/bearfrontal0091.jpg
#   inflating: Image/BearHead/bearfrontal0058.jpg
#   inflating: Image/BearHead/bearfrontal0014.jpg
#   inflating: Image/BearHead/bearfrontal0020.jpg
#   inflating: Image/BearHead/bearfrontal0043.jpg
#   inflating: Image/BearHead/bearfrontal0062.jpg
#   inflating: Image/BearHead/bearfrontal0001.jpg
#   inflating: Image/BearHead/bearfrontal0026.jpg
#   inflating: Image/BearHead/bearfrontal0068.jpg
#   inflating: Image/BearHead/bearfrontal0003.jpg
#   inflating: Image/BearHead/bearfrontal0004.jpg
#   inflating: Image/BearHead/bearfrontal0098.jpg
#   inflating: Image/BearHead/bearfrontal0057.jpg
#   inflating: Image/BearHead/bearfrontal0086.jpg
#   inflating: Image/BearHead/bearfrontal0093.jpg
#   inflating: Image/BearHead/bearfrontal0092.jpg
#   inflating: Image/BearHead/bearfrontal0015.jpg
#   inflating: Image/BearHead/bearfrontal0022.jpg
#   inflating: Image/BearHead/bearfrontal0037.jpg
#   inflating: Image/BearHead/bearfrontal0090.jpg
#   inflating: Image/BearHead/bearfrontal0029.jpg
#   inflating: Image/BearHead/bearfrontal0076.jpg
#   inflating: Image/BearHead/bearfrontal0071.jpg
#   inflating: Image/BearHead/bearfrontal0095.jpg
#   inflating: Image/BearHead/bearfrontal0033.jpg
#   inflating: Image/BearHead/bearfrontal0064.jpg
#   inflating: Image/BearHead/polar-bear-tongue.jpg
#   inflating: Image/BearHead/bearfrontal0002.jpg
#   inflating: Image/BearHead/bearfrontal0060.jpg
#   inflating: Image/BearHead/bearfrontal0051.jpg
#   inflating: Image/BearHead/bearfrontal0075.jpg
#   inflating: Image/BearHead/bearfrontal0055.jpg
#   inflating: Image/BearHead/bearfrontal0052.jpg
#   inflating: Image/BearHead/bearfrontal0006.jpg
#   inflating: Image/BearHead/bearfrontal0069.jpg
#   inflating: Image/BearHead/bearfrontal0038.jpg
#   inflating: Image/BearHead/bearfrontal0056.jpg
#   inflating: Image/BearHead/bearfrontal0021.jpg
#   inflating: Image/BearHead/bearfrontal0044.jpg
#   inflating: Image/BearHead/bearfrontal0012.jpg
#   inflating: Image/BearHead/bearfrontal0088.jpg
#   inflating: Image/BearHead/bearfrontal0067.jpg
#   inflating: Image/BearHead/bearfrontal0047.jpg
#   inflating: Image/BearHead/bearfrontal0094.jpg
#   inflating: Image/BearHead/bearfrontal0054.jpg
#   inflating: Image/BearHead/bearfrontal0009.jpg
#   inflating: Image/BearHead/bearfrontal0035.jpg
#   inflating: Image/BearHead/bearfrontal0011.jpg
#   inflating: Image/BearHead/bearfrontal0028.jpg
#   inflating: Image/BearHead/bearfrontal0031.jpg
#   inflating: Image/BearHead/bearfrontal0061.jpg
#   inflating: Image/BearHead/bearfrontal0024.jpg
#   inflating: Image/BearHead/bearfrontal0096.jpg
#   inflating: Image/BearHead/bearfrontal0039.jpg
#   inflating: Image/BearHead/bearfrontal0040.jpg
#   inflating: Image/BearHead/bearfrontal0019.jpg
#   inflating: Image/CowHead/1846375599_f0190f706a.jpg
#   inflating: Image/CowHead/cattlefrontal0082.jpg
#   inflating: Image/CowHead/Highland_Cow.jpg
#   inflating: Image/CowHead/cattlefrontal0027.jpg
#   inflating: Image/CowHead/cattlefrontal0100.jpg
#   inflating: Image/CowHead/cattlefrontal0037.jpg
#   inflating: Image/CowHead/1-brown-cow-louise-magno.jpg
#   inflating: Image/CowHead/cattlefrontal0033.jpg
#   inflating: Image/CowHead/cow-gross-outs.jpg
#   inflating: Image/CowHead/cattlefrontal0001.jpg
#   inflating: Image/CowHead/cattlefrontal0040.jpg
#   inflating: Image/CowHead/cattlefrontal0039.jpg
#   inflating: Image/CowHead/Sussex_cow_4.jpg
#   inflating: Image/CowHead/cattlefrontal0014.jpg
#   inflating: Image/CowHead/cattlefrontal0058.jpg
#   inflating: Image/CowHead/cattlefrontal0007.jpg
#   inflating: Image/CowHead/cattlefrontal0071.jpg
#   inflating: Image/CowHead/cattlefrontal0036.jpg
#   inflating: Image/CowHead/cattlefrontal0045.jpg
#   inflating: Image/CowHead/cattlefrontal0065.jpg
#   inflating: Image/CowHead/cattlefrontal0089.jpg
#   inflating: Image/CowHead/cattlefrontal0067.jpg
#   inflating: Image/CowHead/cattlefrontal0017.jpg
#   inflating: Image/CowHead/Cow_With_RFID_Tag.jpg
#   inflating: Image/CowHead/cattlefrontal0068.jpg
#   inflating: Image/CowHead/cow1.gif
#   inflating: Image/CowHead/k3219916.jpg
#   inflating: Image/CowHead/COW (2).jpg
#   inflating: Image/CowHead/cattlefrontal0003.jpg
#   inflating: Image/CowHead/cattlefrontal0005.jpg
#   inflating: Image/CowHead/cattlefrontal0051.jpg
#   inflating: Image/CowHead/cattlefrontal0022.jpg
#   inflating: Image/CowHead/cattlefrontal0072.jpg
#   inflating: Image/CowHead/cattlefrontal0075.jpg
#   inflating: Image/CowHead/cattlefrontal0094.jpg
#   inflating: Image/CowHead/cattlefrontal0092.jpg
#   inflating: Image/CowHead/cattlefrontal0025.jpg
#   inflating: Image/CowHead/cattlefrontal0047.jpg
#   inflating: Image/CowHead/cattlefrontal0074.jpg
#   inflating: Image/CowHead/cattlefrontal0099.jpg
#   inflating: Image/CowHead/cattlefrontal0016.jpg
#   inflating: Image/CowHead/pd2197652.jpg
#   inflating: Image/CowHead/cattlefrontal0018.jpg
#   inflating: Image/CowHead/Cow 13.jpg
#   inflating: Image/CowHead/cattlefrontal0004.jpg
#   inflating: Image/CowHead/cattlefrontal0024.jpg
#   inflating: Image/CowHead/cattlefrontal0087.jpg
#   inflating: Image/CowHead/cattlefrontal0041.jpg
#   inflating: Image/CowHead/cattlefrontal0084.jpg
#   inflating: Image/CowHead/050963A.JPG
#   inflating: Image/CowHead/cattlefrontal0073.jpg
#   inflating: Image/CowHead/cow.jpg
#   inflating: Image/CowHead/cattlefrontal0093.jpg
#   inflating: Image/CowHead/cattlefrontal0060.jpg
#   inflating: Image/CowHead/cattlefrontal0031.jpg
#   inflating: Image/CowHead/cattlefrontal0091.jpg
#   inflating: Image/CowHead/cattlefrontal0054.jpg
#   inflating: Image/CowHead/Cow_rt6_web_edited-1.jpg
#   inflating: Image/CowHead/cattlefrontal0086.jpg
#   inflating: Image/CowHead/cattlefrontal0059.jpg
#   inflating: Image/CowHead/cattlefrontal0096.jpg
#   inflating: Image/CowHead/cow-black.jpg
#   inflating: Image/CowHead/cattlefrontal0023.jpg
#   inflating: Image/CowHead/cattlefrontal0020.jpg
#   inflating: Image/CowHead/cattlefrontal0044.jpg
#   inflating: Image/CowHead/cattlefrontal0043.jpg
#   inflating: Image/CowHead/cattlefrontal0069.jpg
#   inflating: Image/CowHead/cattlefrontal0002.jpg
#   inflating: Image/CowHead/cattlefrontal0019.jpg
#   inflating: Image/CowHead/cattlefrontal0053.jpg
#   inflating: Image/CowHead/cows-324x205.jpg
#   inflating: Image/CowHead/A22A0X.jpg
#   inflating: Image/CowHead/cattlefrontal0095.jpg
#   inflating: Image/CowHead/73870944qUylUu_fs.jpg
#   inflating: Image/CowHead/cattlefrontal0010.jpg
#   inflating: Image/CowHead/cattlefrontal0052.jpg
#   inflating: Image/CowHead/cattlefrontal0013.jpg
#   inflating: Image/CowHead/cattlefrontal0011.jpg
#   inflating: Image/CowHead/cattlefrontal0028.jpg
#   inflating: Image/CowHead/cattlefrontal0066.jpg
#   inflating: Image/CowHead/cattlefrontal0097.jpg
#   inflating: Image/CowHead/cattlefrontal0064.jpg
#   inflating: Image/CowHead/cattlefrontal0085.jpg
#   inflating: Image/CowHead/cattlefrontal0055.jpg
#   inflating: Image/CowHead/cattlefrontal0049.jpg
#   inflating: Image/CowHead/cattlefrontal0098.jpg
#   inflating: Image/CowHead/cattlefrontal0015.jpg
#   inflating: Image/CowHead/cow1.jpg
#   inflating: Image/CowHead/cattlefrontal0063.jpg
#   inflating: Image/CowHead/cattlefrontal0061.jpg
#   inflating: Image/CowHead/cattlefrontal0021.jpg
#   inflating: Image/CowHead/cattlefrontal0034.jpg
#   inflating: Image/CowHead/cow (3).jpg
#   inflating: Image/CowHead/cow (1).jpg
#   inflating: Image/CowHead/01_05_21---Cow_web.jpg
#   inflating: Image/CowHead/cattlefrontal0029.jpg
#   inflating: Image/CowHead/cattlefrontal0035.jpg
#   inflating: Image/CowHead/cattlefrontal0046.jpg
#   inflating: Image/CowHead/brown cow 2.jpg
#   inflating: Image/CowHead/542696674_1a7a164508.jpg
#   inflating: Image/CowHead/GSP0001140_P.JPG
#   inflating: Image/CowHead/cattlefrontal0090.jpg
#   inflating: Image/CowHead/cattlefrontal0062.jpg
#   inflating: Image/CowHead/cattlefrontal0077.jpg
#   inflating: Image/TigerHead/tiger0000000067.jpg
#   inflating: Image/TigerHead/tiger0000000773.jpg
#   inflating: Image/TigerHead/tiger0000000042.jpg
#   inflating: Image/TigerHead/Bengal_Tiger.jpg
#   inflating: Image/TigerHead/tiger0000000133.jpg
#   inflating: Image/TigerHead/tiger0000000509.jpg
#   inflating: Image/TigerHead/tiger0000000045.jpg
#   inflating: Image/TigerHead/tiger0000000073.jpg
#   inflating: Image/TigerHead/tiger0000000513.jpg
#   inflating: Image/TigerHead/tiger0000000200.jpg
#   inflating: Image/TigerHead/tiger0000000169.jpg
#   inflating: Image/TigerHead/tiger0000000085.jpg
#   inflating: Image/TigerHead/siberian_tiger.jpg
#   inflating: Image/TigerHead/tiger0000000129.jpg
#   inflating: Image/TigerHead/tiger0000000761.jpg
#   inflating: Image/TigerHead/tiger0000000051.jpg
#   inflating: Image/TigerHead/tiger0000000151.jpg
#   inflating: Image/TigerHead/tiger0000000531.jpg
#   inflating: Image/TigerHead/tiger0000000002.jpg
#   inflating: Image/TigerHead/tiger0000000016.jpg
#   inflating: Image/TigerHead/tiger0000000012.jpg
#   inflating: Image/TigerHead/tiger0000000023.jpg
#   inflating: Image/TigerHead/tiger0000000043.jpg
#   inflating: Image/TigerHead/tiger0000000537.jpg
#   inflating: Image/TigerHead/tiger0000000181.jpg
#   inflating: Image/TigerHead/tiger0000000166.jpg
#   inflating: Image/TigerHead/tiger0000000770.jpg
#   inflating: Image/TigerHead/tiger0000000080.jpg
#   inflating: Image/TigerHead/tiger0000000046.jpg
#   inflating: Image/TigerHead/tiger0000000757.jpg
#   inflating: Image/TigerHead/tiger0000000060.jpg
#   inflating: Image/TigerHead/tigers.JPG
#   inflating: Image/TigerHead/tiger0000000758.jpg
#   inflating: Image/TigerHead/tiger0000000536.jpg
#   inflating: Image/TigerHead/tiger0000000173.jpg
#   inflating: Image/TigerHead/tiger0000000506.jpg
#   inflating: Image/TigerHead/tiger0000000066.jpg
#   inflating: Image/TigerHead/tiger0000000127.jpg
#   inflating: Image/TigerHead/tiger (1).jpg
#   inflating: Image/TigerHead/indochinese-tiger-eaten.jpg
#   inflating: Image/TigerHead/tiger0000000148.jpg
#   inflating: Image/TigerHead/tiger0000000010.jpg
#   inflating: Image/TigerHead/tiger0000000196.jpg
#   inflating: Image/TigerHead/tiger0000000076.jpg
#   inflating: Image/TigerHead/volunteer-with-a-tiger.jpg
#   inflating: Image/TigerHead/tiger0000000534.jpg
#   inflating: Image/TigerHead/tiger0000000117.jpg
#   inflating: Image/TigerHead/tiger0000000768.jpg
#   inflating: Image/TigerHead/tiger0000000772.jpg
#   inflating: Image/TigerHead/tiger0000000195.jpg
#   inflating: Image/TigerHead/tiger0000000005.jpg
#   inflating: Image/TigerHead/tiger0000000524.jpg
#   inflating: Image/TigerHead/_1768316_tiger4.jpg
#   inflating: Image/TigerHead/tiger0000000165.jpg
#   inflating: Image/TigerHead/tiger.jpg
#   inflating: Image/TigerHead/tiger0000000056.jpg
#   inflating: Image/TigerHead/tiger0000000514.jpg
#   inflating: Image/TigerHead/tiger0000000756.jpg
#   inflating: Image/TigerHead/tiger0000000050.jpg
#   inflating: Image/TigerHead/tiger0000000070.jpg
#   inflating: Image/TigerHead/tiger0000000030.jpg
#   inflating: Image/TigerHead/tiger0000000168.jpg
#   inflating: Image/TigerHead/tiger-photo-00002.jpg
#   inflating: Image/TigerHead/tiger0000000086.jpg
#   inflating: Image/TigerHead/tiger0000000018.jpg
#   inflating: Image/TigerHead/tiger0000000024.jpg
#   inflating: Image/TigerHead/tiger0000000065.jpg
#   inflating: Image/TigerHead/tiger_running_in_snow.jpg
#   inflating: Image/TigerHead/south-china-tiger-350x254.jpg
#   inflating: Image/TigerHead/tiger0000000507.jpg
#   inflating: Image/TigerHead/tiger0000000047.jpg
#   inflating: Image/TigerHead/tiger-attack.jpg
#   inflating: Image/TigerHead/tiger0000000766.jpg
#   inflating: Image/TigerHead/bengal_tiger_31.jpg
#   inflating: Image/TigerHead/tiger0000000206.jpg
#   inflating: Image/TigerHead/tiger0000000193.jpg
#   inflating: Image/TigerHead/tiger0000000157.jpg
#   inflating: Image/TigerHead/tiger0000000003.jpg
#   inflating: Image/TigerHead/tiger0000000764.jpg
#   inflating: Image/TigerHead/tiger0000000150.jpg
#   inflating: Image/TigerHead/tiger0000000759.jpg
#   inflating: Image/TigerHead/tiger0000000510.jpg
#   inflating: Image/TigerHead/tiger0000000061.jpg
#   inflating: Image/TigerHead/tiger0000000029.jpg
#   inflating: Image/TigerHead/tiger0000000033.jpg
#   inflating: Image/TigerHead/tiger0000000038.jpg
#   inflating: Image/TigerHead/tiger_540x315.jpg
#   inflating: Image/TigerHead/tiger0000000027.jpg
#   inflating: Image/TigerHead/tiger0000000520.jpg
#   inflating: Image/TigerHead/tiger0000000186.jpg
#   inflating: Image/TigerHead/lying-tiger-1a.jpg
#   inflating: Image/TigerHead/Siberian-Tiger.jpg
#   inflating: Image/TigerHead/2_tigers.jpg
#   inflating: Image/TigerHead/tiger0000000014.jpg
#   inflating: Image/TigerHead/tiger0000000174.jpg
#   inflating: Image/TigerHead/tiger0000000004.jpg
#   inflating: Image/TigerHead/tiger0000000763.jpg
#   inflating: Image/TigerHead/tiger0000000187.jpg
#   inflating: Image/TigerHead/tiger0000000141.jpg
#   inflating: Image/TigerHead/tiger0000000098.jpg
#   inflating: Image/TigerHead/1235_white-baby-tiger.jpg
#   inflating: Image/TigerHead/ron-kimball-white-tiger-sitting.jpg
#   inflating: Image/TigerHead/tiger-swimming.jpg
#   inflating: Image/TigerHead/tiger0000000128.jpg
#   inflating: Image/TigerHead/tiger0000000022.jpg
#   inflating: Image/TigerHead/siberian-tiger-grooming.jpg
#   inflating: Image/TigerHead/tiger-tatiana.gif
#   inflating: Image/TigerHead/tiger0000000053.jpg
#   inflating: Image/TigerHead/tiger0000000760.jpg
#   inflating: Image/TigerHead/tiger0000000083.jpg
#   inflating: Image/TigerHead/tiger0000000093.jpg
#   inflating: Image/TigerHead/tiger0000000518.jpg
#   inflating: Image/TigerHead/me-and-a-tiger-2007.jpg
#   inflating: Image/TigerHead/tiger0000000088.jpg
#   inflating: Image/WolfHead/wolffrontal0025.jpg
#   inflating: Image/WolfHead/wolffrontal0063.jpg
#   inflating: Image/WolfHead/wolffrontal0055.jpg
#   inflating: Image/WolfHead/wolffrontal0039.jpg
#   inflating: Image/WolfHead/wolffrontal0031.jpg
# ...
#   inflating: Image/HumanHead/0000000044.jpg
#   inflating: Image/HumanHead/0000000130.jpg
#   inflating: Image/HumanHead/0000000047.jpg
#   inflating: Image/HumanHead/0000000117.jpg
#   inflating: Image/HumanHead/0000000100.jpg
#   inflating: Image/HumanHead/0000000084.jpg
#   inflating: Image/HumanHead/0000000111.jpg
#   inflating: Image/HumanHead/0000000015.jpg
#   inflating: Image/HumanHead/0000000083.jpg
#   inflating: Image/HumanHead/0000000062.jpg
#   inflating: Image/HumanHead/0000000008.jpg
#   inflating: Image/HumanHead/0000000006.jpg
#   inflating: Image/HumanHead/0000000001.jpg
#   inflating: Image/HumanHead/0000000081.jpg
#   inflating: Image/HumanHead/0000000078.jpg
#   inflating: Image/HumanHead/0000000077.jpg
#   inflating: Image/HumanHead/0000000122.jpg
#   inflating: Image/HumanHead/0000000088.jpg
#   inflating: Image/HumanHead/0000000098.jpg
#   inflating: Image/HumanHead/0000000016.jpg
#   inflating: Image/HumanHead/0000000116.jpg
#   inflating: Image/HumanHead/0000000119.jpg
#   inflating: Image/HumanHead/0000000052.jpg
#   inflating: Image/HumanHead/0000000114.jpg
#   inflating: Image/HumanHead/0000000104.jpg
#   inflating: Image/HumanHead/0000000046.jpg
#   inflating: Image/HumanHead/0000000123.jpg
#   inflating: Image/HumanHead/0000000097.jpg
#   inflating: Image/HumanHead/0000000109.jpg
#   inflating: Image/HumanHead/0000000095.jpg
#   inflating: Image/HumanHead/0000000025.jpg
#   inflating: Image/HumanHead/0000000065.jpg
#   inflating: Image/HumanHead/0000000079.jpg
#   inflating: Image/HumanHead/0000000054.jpg
#   inflating: Image/HumanHead/0000000010.jpg
#   inflating: Image/HumanHead/0000000085.jpg
#   inflating: Image/HumanHead/0000000096.jpg
#   inflating: Image/HumanHead/0000000120.jpg
#   inflating: Image/HumanHead/0000000023.jpg
#   inflating: Image/HumanHead/0000000131.jpg
#   inflating: Image/HumanHead/0000000099.jpg
#   inflating: Image/HumanHead/0000000118.jpg
#   inflating: Image/HumanHead/0000000103.jpg
#   inflating: Image/HumanHead/0000000129.jpg
#   inflating: Image/HumanHead/0000000017.jpg
#   inflating: Image/HumanHead/0000000091.jpg
#   inflating: Image/HumanHead/0000000092.jpg
#   inflating: Image/HumanHead/0000000067.jpg
#   inflating: Image/HumanHead/0000000064.jpg
#   inflating: Image/HumanHead/0000000102.jpg
#   inflating: Image/HumanHead/0000000089.jpg
#   inflating: Image/HumanHead/0000000076.jpg
#   inflating: Image/HumanHead/0000000063.jpg
#   inflating: Image/HumanHead/0000000070.jpg
#   inflating: Image/HumanHead/0000000121.jpg
#   inflating: Image/HumanHead/0000000128.jpg
#   inflating: Image/HumanHead/0000000074.jpg
#   inflating: Image/HumanHead/0000000087.jpg
#   inflating: Image/HumanHead/0000000101.jpg
#   inflating: Image/HumanHead/0000000094.jpg
#   inflating: Image/HumanHead/0000000073.jpg
#   inflating: Image/HumanHead/0000000024.jpg
#   inflating: Image/HumanHead/0000000090.jpg
#   inflating: Image/HumanHead/0000000045.jpg
#   inflating: Image/HumanHead/0000000059.jpg
#   inflating: Image/HumanHead/0000000048.jpg
#   inflating: Image/HumanHead/0000000014.jpg
#   inflating: Image/HumanHead/0000000093.jpg
#   inflating: Image/HumanHead/0000000112.jpg
#   inflating: Image/HumanHead/0000000055.jpg
#   inflating: Image/HumanHead/0000000019.jpg
#   inflating: Image/HumanHead/0000000107.jpg
#   inflating: Image/HumanHead/0000000056.jpg
#   inflating: Image/HumanHead/0000000108.jpg
#   inflating: Image/HumanHead/0000000125.jpg
#   inflating: Image/HumanHead/0000000110.jpg
#   inflating: Image/HumanHead/0000000086.jpg
#   inflating: Image/HumanHead/0000000057.jpg
#   inflating: Image/HumanHead/0000000105.jpg
#   inflating: Image/HumanHead/0000000020.jpg
#   inflating: Image/HumanHead/0000000124.jpg
#   inflating: Image/HumanHead/0000000126.jpg
#   inflating: Image/HumanHead/0000000031.jpg
#   inflating: Image/HumanHead/0000000061.jpg
#   inflating: Image/HumanHead/0000000043.jpg
#   inflating: Image/HumanHead/0000000066.jpg
#   inflating: Image/HumanHead/0000000082.jpg
#   inflating: Image/HumanHead/0000000072.jpg
#   inflating: Image/HumanHead/0000000071.jpg
#   inflating: Image/HumanHead/0000000080.jpg
#   inflating: Image/HumanHead/0000000113.jpg
#   inflating: Image/SheepHead/sheepfrontal0038.jpg
#   inflating: Image/SheepHead/sheepfrontal0079.jpg
#   inflating: Image/SheepHead/sheepfrontal0027.jpg
#   inflating: Image/SheepHead/sheepfrontal0003.jpg
#   inflating: Image/SheepHead/sheepfrontal0041.jpg
#   inflating: Image/SheepHead/sheepfrontal0083.jpg
#   inflating: Image/SheepHead/sheepfrontal0049.jpg
#   inflating: Image/SheepHead/sheepfrontal0046.jpg
#   inflating: Image/SheepHead/sheepfrontal0042.jpg
#   inflating: Image/SheepHead/sheepfrontal0023.jpg
#   inflating: Image/SheepHead/sheepfrontal0089.jpg
#   inflating: Image/SheepHead/sheepfrontal0019.jpg
#   inflating: Image/SheepHead/sheepfrontal0077.jpg
#   inflating: Image/SheepHead/sheepfrontal0014.jpg
#   inflating: Image/SheepHead/sheepfrontal0091.jpg
#   inflating: Image/SheepHead/sheepfrontal0059.jpg
#   inflating: Image/SheepHead/sheepfrontal0097.jpg
#   inflating: Image/SheepHead/sheepfrontal0036.jpg
#   inflating: Image/SheepHead/sheepfrontal0011.jpg
#   inflating: Image/SheepHead/sheepfrontal0004.jpg
#   inflating: Image/SheepHead/sheepfrontal0056.jpg
#   inflating: Image/SheepHead/sheepfrontal0100.jpg
#   inflating: Image/SheepHead/sheepfrontal0007.jpg
#   inflating: Image/SheepHead/sheepfrontal0032.jpg
#   inflating: Image/SheepHead/sheepfrontal0078.jpg
#   inflating: Image/SheepHead/sheepfrontal0028.jpg
#   inflating: Image/SheepHead/sheepfrontal0090.jpg
#   inflating: Image/SheepHead/sheepfrontal0093.jpg
#   inflating: Image/SheepHead/sheepfrontal0048.jpg
#   inflating: Image/SheepHead/sheepfrontal0006.jpg
#   inflating: Image/SheepHead/sheepfrontal0062.jpg
#   inflating: Image/SheepHead/sheepfrontal0002.jpg
#   inflating: Image/SheepHead/sheepfrontal0050.jpg
#   inflating: Image/SheepHead/sheepfrontal0025.jpg
#   inflating: Image/SheepHead/sheepfrontal0030.jpg
#   inflating: Image/SheepHead/sheepfrontal0067.jpg
#   inflating: Image/SheepHead/sheepfrontal0066.jpg
#   inflating: Image/SheepHead/sheepfrontal0017.jpg
#   inflating: Image/SheepHead/sheepfrontal0098.jpg
#   inflating: Image/SheepHead/sheepfrontal0033.jpg
#   inflating: Image/SheepHead/sheepfrontal0085.jpg
#   inflating: Image/SheepHead/sheepfrontal0043.jpg
#   inflating: Image/SheepHead/sheepfrontal0075.jpg
#   inflating: Image/SheepHead/sheepfrontal0061.jpg
#   inflating: Image/SheepHead/sheepfrontal0092.jpg
#   inflating: Image/SheepHead/sheepfrontal0022.jpg
#   inflating: Image/SheepHead/sheepfrontal0076.jpg
#   inflating: Image/SheepHead/sheepfrontal0080.jpg
#   inflating: Image/SheepHead/sheepfrontal0045.jpg
#   inflating: Image/SheepHead/sheepfrontal0055.jpg
#   inflating: Image/SheepHead/sheepfrontal0057.jpg
#   inflating: Image/SheepHead/sheepfrontal0072.jpg
#   inflating: Image/SheepHead/sheepfrontal0086.jpg
#   inflating: Image/SheepHead/sheepfrontal0058.jpg
#   inflating: Image/SheepHead/sheepfrontal0015.jpg
#   inflating: Image/SheepHead/sheepfrontal0064.jpg
#   inflating: Image/SheepHead/sheepfrontal0060.jpg
#   inflating: Image/SheepHead/sheepfrontal0031.jpg
#   inflating: Image/SheepHead/sheepfrontal0073.jpg
#   inflating: Image/SheepHead/sheepfrontal0024.jpg
#   inflating: Image/SheepHead/sheepfrontal0009.jpg
#   inflating: Image/SheepHead/sheepfrontal0082.jpg
#   inflating: Image/SheepHead/sheepfrontal0021.jpg
#   inflating: Image/SheepHead/sheepfrontal0096.jpg
#   inflating: Image/SheepHead/sheepfrontal0052.jpg
#   inflating: Image/SheepHead/sheepfrontal0012.jpg
#   inflating: Image/SheepHead/sheepfrontal0020.jpg
#   inflating: Image/SheepHead/sheepfrontal0088.jpg
#   inflating: Image/SheepHead/sheepfrontal0013.jpg
#   inflating: Image/SheepHead/sheepfrontal0001.jpg
#   inflating: Image/SheepHead/sheepfrontal0087.jpg
#   inflating: Image/SheepHead/sheepfrontal0071.jpg
#   inflating: Image/SheepHead/sheepfrontal0039.jpg
#   inflating: Image/SheepHead/sheepfrontal0047.jpg
#   inflating: Image/SheepHead/sheepfrontal0005.jpg
#   inflating: Image/SheepHead/sheepfrontal0054.jpg
#   inflating: Image/SheepHead/sheepfrontal0068.jpg
#   inflating: Image/SheepHead/sheepfrontal0084.jpg
#   inflating: Image/SheepHead/sheepfrontal0051.jpg
#   inflating: Image/SheepHead/sheepfrontal0008.jpg
#   inflating: Image/SheepHead/sheepfrontal0037.jpg
#   inflating: Image/SheepHead/sheepfrontal0065.jpg
#   inflating: Image/SheepHead/sheepfrontal0034.jpg
#   inflating: Image/SheepHead/sheepfrontal0081.jpg
#   inflating: Image/SheepHead/sheepfrontal0044.jpg
#   inflating: Image/SheepHead/sheepfrontal0040.jpg
#   inflating: Image/SheepHead/sheepfrontal0010.jpg
#   inflating: Image/SheepHead/sheepfrontal0074.jpg
#   inflating: Image/SheepHead/sheepfrontal0070.jpg
#   inflating: Image/SheepHead/sheepfrontal0099.jpg
#   inflating: Image/SheepHead/sheepfrontal0016.jpg
#   inflating: Image/SheepHead/sheepfrontal0053.jpg
#   inflating: Image/SheepHead/sheepfrontal0018.jpg
#   inflating: Image/SheepHead/sheepfrontal0035.jpg
#   inflating: Image/SheepHead/sheepfrontal0026.jpg
#   inflating: Image/SheepHead/sheepfrontal0094.jpg
#   inflating: Image/SheepHead/sheepfrontal0063.jpg
#   inflating: Image/SheepHead/sheepfrontal0069.jpg
#   inflating: Image/SheepHead/sheepfrontal0095.jpg
#   inflating: Image/SheepHead/sheepfrontal0029.jpg
#   inflating: Image/CatHead/cat873a.jpg
#   inflating: Image/CatHead/cat489a.jpg
#   inflating: Image/CatHead/cat820b.jpg
#   inflating: Image/CatHead/cat864a.jpg
#   inflating: Image/CatHead/cat774b.jpg
#   inflating: Image/CatHead/cat777a.jpg
#   inflating: Image/CatHead/cat516a.jpg
#   inflating: Image/CatHead/cat965a.jpg
#   inflating: Image/CatHead/cat453a.jpg
#   inflating: Image/CatHead/cat1060a.bmp
#   inflating: Image/CatHead/cat454a.jpg
#   inflating: Image/CatHead/cat861b.jpg
#   inflating: Image/CatHead/cat702a.jpg
#   inflating: Image/CatHead/cat537a.jpg
#   inflating: Image/CatHead/cat765a.jpg
#   inflating: Image/CatHead/cat498a.jpg
#   inflating: Image/CatHead/cat995a.jpg
#   inflating: Image/CatHead/cat518a.jpg
#   inflating: Image/CatHead/cat986a.jpg
#   inflating: Image/CatHead/cat000908.jpg
#   inflating: Image/CatHead/cat549a.jpg
#   inflating: Image/CatHead/cat846a.jpg
#   inflating: Image/CatHead/cat776a.jpg
#   inflating: Image/CatHead/cat756a.jpg
#   inflating: Image/CatHead/cat491a.jpg
#   inflating: Image/CatHead/cat497a.jpg
#   inflating: Image/CatHead/cat565a.jpg
#   inflating: Image/CatHead/cat771b.jpg
#   inflating: Image/CatHead/cat779ajpg.jpg
#   inflating: Image/CatHead/cat665a.jpg
#   inflating: Image/CatHead/cat457a.jpg
#   inflating: Image/CatHead/cat924a.jpg
#   inflating: Image/CatHead/cat716a.jpg
#   inflating: Image/CatHead/cat746a.jpg
#   inflating: Image/CatHead/cat517a.jpg
#   inflating: Image/CatHead/cat865a.jpg
#   inflating: Image/CatHead/cat615a.jpg
#   inflating: Image/CatHead/cat1024a.jpg
#   inflating: Image/CatHead/cat1033a.jpg
#   inflating: Image/CatHead/cat781a.jpg
#   inflating: Image/CatHead/cat931a.jpg
#   inflating: Image/CatHead/cat863a.jpg
#   inflating: Image/CatHead/cat504a.jpg
#   inflating: Image/CatHead/cat992a.jpg
#   inflating: Image/CatHead/cat673a.jpg
#   inflating: Image/CatHead/cat958a.jpg
#   inflating: Image/CatHead/cat468a.jpg
#   inflating: Image/CatHead/cat764a.jpg
#   inflating: Image/CatHead/cat1053a.jpg
#   inflating: Image/CatHead/cat860a.jpg
#   inflating: Image/CatHead/cat750a.jpg
#   inflating: Image/CatHead/cat1004a.jpg
#   inflating: Image/CatHead/cat913a.jpg
#   inflating: Image/CatHead/cat503a.jpg
#   inflating: Image/CatHead/cat512a.jpg
#   inflating: Image/CatHead/cat536d.jpg
#   inflating: Image/CatHead/cat1022a.jpg
#   inflating: Image/CatHead/cat844a.jpg
#   inflating: Image/CatHead/cat751a.jpg
#   inflating: Image/CatHead/cat645a.jpg
#   inflating: Image/CatHead/cat781b.jpg
#   inflating: Image/CatHead/cat780a.jpg
#   inflating: Image/CatHead/cat730a.jpg
#   inflating: Image/CatHead/cat474a.jpg
#   inflating: Image/CatHead/cat1012a.jpg
#   inflating: Image/CatHead/cat694a.jpg
#   inflating: Image/CatHead/cat469a.jpg
#   inflating: Image/CatHead/cat866.jpg
#   inflating: Image/CatHead/cat738a..jpg
#   inflating: Image/CatHead/cat848a.jpg
#   inflating: Image/CatHead/cat749a.jpg
#   inflating: Image/CatHead/cat519a.jpg
#   inflating: Image/CatHead/cat521a.jpg
#   inflating: Image/CatHead/cat1058a.jpg
#   inflating: Image/CatHead/cat869a.jpg
#   inflating: Image/CatHead/cat000852.jpg
#   inflating: Image/CatHead/cat879a.jpg
#   inflating: Image/CatHead/cat717a.jpg
#   inflating: Image/CatHead/cat646a.jpg
#   inflating: Image/CatHead/cat843a.jpg
#   inflating: Image/CatHead/cat1031b.jpg
#   inflating: Image/CatHead/cat472a.jpg
#   inflating: Image/CatHead/cat710a.jpg
#   inflating: Image/CatHead/cat1020b.jpg
#   inflating: Image/CatHead/cat479a.jpg
#   inflating: Image/CatHead/cat000960.jpg
#   inflating: Image/CatHead/cat459a.jpg
#   inflating: Image/CatHead/cat1027a.jpg
#   inflating: Image/CatHead/cat782a.jpg
#   inflating: Image/CatHead/cat781c.jpg
#   inflating: Image/CatHead/cat739a.jpg
#   inflating: Image/CatHead/cat736a.jpg
#   inflating: Image/CatHead/cat770a.jpg
#   inflating: Image/CatHead/cat000967.jpg
#   inflating: Image/CatHead/cat747a.jpg
#   inflating: Image/CatHead/cat562a.jpg
#   inflating: Image/CatHead/cat696a.jpg
#   inflating: Image/CatHead/cat830a.jpg
#   inflating: Image/CatHead/cat723a.jpg
#   inflating: Image/CatHead/cat786a.jpg
#   inflating: Image/CatHead/cat513a.jpg
#   inflating: Image/CatHead/cat784a.jpg
#   inflating: Image/CatHead/cat778a.jpg
#   inflating: Image/CatHead/cat527a.jpg
#   inflating: Image/CatHead/cat886c.jpg
#   inflating: Image/CatHead/cat460a.jpg
#   inflating: Image/CatHead/cat751b.jpg
#   inflating: Image/CatHead/cat805a.jpg
#   inflating: Image/CatHead/cat893b.jpg
#   inflating: Image/CatHead/cat647a.jpg
#   inflating: Image/CatHead/cat564a.jpg
#   inflating: Image/CatHead/cat664a.jpg
#   inflating: Image/CatHead/cat1021a.jpg
#   inflating: Image/CatHead/cat776b.jpg
#   inflating: Image/CatHead/cat862a.jpg
#   inflating: Image/CatHead/cat760a.jpg
#   inflating: Image/CatHead/cat515a.jpg
#   inflating: Image/CatHead/cat990a.jpg
#   inflating: Image/CatHead/cat547b.jpg
#   inflating: Image/CatHead/cat893a.jpg
#   inflating: Image/CatHead/cat728a.jpg
#   inflating: Image/CatHead/cat485a.jpg
#   inflating: Image/CatHead/cat684a.jpg
#   inflating: Image/CatHead/cat775a.jpg
#   inflating: Image/CatHead/cat570a.jpg
#   inflating: Image/CatHead/cat471a.jpg
#   inflating: Image/CatHead/cat744a.jpg
#   inflating: Image/CatHead/cat1054a.jpg
#   inflating: Image/CatHead/cat707a.jpg
#   inflating: Image/CatHead/cat985a.jpg
#   inflating: Image/CatHead/cat816a.jpg
#   inflating: Image/CatHead/cat795a.jpg
#   inflating: Image/CatHead/cat450a.jpg
#   inflating: Image/CatHead/cat801b.jpg
#   inflating: Image/CatHead/cat547a.jpg
#   inflating: Image/CatHead/cat663a.jpg
#   inflating: Image/CatHead/cat697a.jpg
#   inflating: Image/CatHead/cat536e.jpg
#   inflating: Image/CatHead/cat689a.jpg
#   inflating: Image/CatHead/cat786d.jpg
#   inflating: Image/CatHead/cat754a.jpg
#   inflating: Image/CatHead/cat861a.jpg
#   inflating: Image/CatHead/cat1015a.jpg
#   inflating: Image/CatHead/cat1051a.jpg
#   inflating: Image/CatHead/cat748a.jpg
#   inflating: Image/CatHead/cat1057a.jpg
#   inflating: Image/CatHead/cat849a.jpg
#   inflating: Image/CatHead/cat872a.jpg
#   inflating: Image/CatHead/cat610a.jpg
#   inflating: Image/CatHead/cat878a.jpg
#   inflating: Image/CatHead/cat1040a.jpg
#   inflating: Image/CatHead/cat714a.jpg
#   inflating: Image/CatHead/cat536a.jpg
#   inflating: Image/CatHead/cat1013a.jpg
#   inflating: Image/CatHead/cat492a.jpg
#   inflating: Image/CatHead/cat528a.jpg
#   inflating: Image/CatHead/cat000929.jpg
#   inflating: Image/CatHead/cat606a.jpg
#   inflating: Image/CatHead/cat520a.jpg
#   inflating: Image/CatHead/cat785a.jpg

# %%
import joblib
from skimage.io import imread
from skimage.transform import resize
 
def resize_all(src, pklname, include, width=150, height=None):
    """
    load images from path, resize them and write them as arrays to a dictionary, 
    together with labels and metadata. The dictionary is written to a pickle file 
    named '{pklname}_{width}x{height}px.pkl'.
     
    Parameter
    ---------
    src: str
        path to data
    pklname: str
        path to output file
    width: int
        target width of the image in pixels
    include: set[str]
        set containing str
    """
     
    height = height if height is not None else width
     
    data = dict()
    data['description'] = 'resized ({0}x{1})animal images in rgb'.format(int(width), int(height))
    data['label'] = []
    data['filename'] = []
    data['data'] = []   
     
    pklname = f"{pklname}_{width}x{height}px.pkl"
 
    # read all images in PATH, resize and write to DESTINATION_PATH
    for subdir in os.listdir(src):
        if subdir in include:
            print(subdir)
            current_path = os.path.join(src, subdir)
 
            for file in os.listdir(current_path):
                if file[-3:] in {'jpg', 'png'}:
                    im = imread(os.path.join(current_path, file))
                    im = resize(im, (width, height)) #[:,:,::-1]
                    data['label'].append(subdir[:-4])
                    data['filename'].append(file)
                    data['data'].append(im)
 
        joblib.dump(data, pklname)

# %%
# modify to fit your system
data_path = fr'Image'
os.listdir(data_path)
# Out:
# ['DeerHead',
#  'DogHead',
#  'TigerHead',
#  'MonkeyHead',
#  'MouseHead',
#  'BearHead',
#  'LionHead',
#  'WolfHead',
#  'RabbitHead',
#  'ChickenHead',
#  'PigeonHead',
#  'CatHead',
#  'EagleHead',
#  'ElephantHead',
#  'PandaHead',
#  'HumanHead',
#  'PigHead',
#  'Natural',
#  'CowHead',
#  'SheepHead',
#  'DuckHead']

# %%
base_name = 'animal_faces'
width = 80
 
include = {'ChickenHead', 'BearHead', 'ElephantHead', 
           'EagleHead', 'DeerHead', 'MonkeyHead', 'PandaHead'}
 
resize_all(src=data_path, pklname=base_name, width=width, include=include)
# Out:
# DeerHead
# MonkeyHead
# BearHead
# ChickenHead
# EagleHead
# ElephantHead
# PandaHead

# %%
from collections import Counter
 
data = joblib.load(f'{base_name}_{width}x{width}px.pkl')
 
print('number of samples: ', len(data['data']))
print('keys: ', list(data.keys()))
print('description: ', data['description'])
print('image shape: ', data['data'][0].shape)
print('labels:', np.unique(data['label']))
 
Counter(data['label'])
# Out:
# number of samples:  716
# keys:  ['description', 'label', 'filename', 'data']
# description:  resized (80x80)animal images in rgb
# image shape:  (80, 80, 3)
# labels: ['Bear' 'Chicken' 'Deer' 'Eagle' 'Elephant' 'Monkey' 'Panda']
# Counter({'Deer': 101,
#          'Monkey': 100,
#          'Bear': 101,
#          'Chicken': 100,
#          'Eagle': 97,
#          'Elephant': 100,
#          'Panda': 117})

# %%
X = np.array(data['data'])
y = np.array(data['label'])

# %% [markdown]
# ## 1. Data split [10 pts]
# 위에서 정의된 데이터를 이용하여 train set과 test set으로 분리하시오.
# 두 set의 비율은 8:2로 지정하고, random_state의 seed는 42로 지정하시오.

# %%
from sklearn.model_selection import train_test_split
 
X_train, X_test, y_train, y_test = train_test_split(
    ##############################
)

# %%
def plot_bar(y, loc='left', relative=True):
    width = 0.35
    if loc == 'left':
        n = -0.5
    elif loc == 'right':
        n = 0.5
     
    # calculate counts per type and sort, to ensure their order
    unique, counts = np.unique(y, return_counts=True)
    sorted_index = np.argsort(unique)
    unique = unique[sorted_index]
     
    if relative:
        # plot as a percentage
        counts = 100*counts[sorted_index]/len(y)
        ylabel_text = '% count'
    else:
        # plot counts
        counts = counts[sorted_index]
        ylabel_text = 'count'
         
    xtemp = np.arange(len(unique))
     
    plt.bar(xtemp + n*width, counts, align='center', alpha=.7, width=width)
    plt.xticks(xtemp, unique, rotation=45)
    plt.xlabel('equipment type')
    plt.ylabel(ylabel_text)
 
plt.suptitle('relative amount of photos per type')
plot_bar(y_train, loc='left')
plot_bar(y_test, loc='right')
plt.legend([
    'train ({0} photos)'.format(len(y_train)), 
    'test ({0} photos)'.format(len(y_test))
]);

# %% [markdown]
# ## Feature Extraction
# 이미지에 대해 feature를 뽑고자 한다.
# 뽑으려는 feature는 HoG (Histogram of Gradient)이다.
# HoG feature는 OpenCV에서 `hog` 라는 이름의 method를 제공한다.

# %%
from skimage.feature import hog
from skimage.io import imread
from skimage.transform import rescale
 
dog = imread('/content/Image/BearHead/bearfrontal0001.jpg', as_gray=True)
 
# scale down the image to one third
dog = rescale(dog, 1/3, mode='reflect')

# calculate the hog and return a visual representation.
dog_hog, dog_hog_img = hog(dog, visualize=True)
 
fig, ax = plt.subplots(1,2)
fig.set_size_inches(8,6)
# remove ticks and their labels
[a.tick_params(bottom=False, left=False, labelbottom=False, labelleft=False) 
    for a in ax]
 
ax[0].imshow(dog, cmap='gray')
ax[0].set_title('dog')
ax[1].imshow(dog_hog_img, cmap='gray')
ax[1].set_title('hog')
plt.show()

# %%
from sklearn.base import BaseEstimator, TransformerMixin
 
class RGB2GrayTransformer(BaseEstimator, TransformerMixin):
    """
    Convert an array of RGB images to grayscale
    """
 
    def __init__(self):
        pass
 
    def fit(self, X, y=None):
        """returns itself"""
        return self
 
    def transform(self, X, y=None):
        """perform the transformation and return an array"""
        return np.array([skimage.color.rgb2gray(img) for img in X])
     
 
class HogTransformer(BaseEstimator, TransformerMixin):
    """
    Expects an array of 2d arrays (1 channel images)
    Calculates hog features for each img
    """
 
    def __init__(self):
      pass
 
    def fit(self, X, y=None):
        return self
 
    def transform(self, X, y=None): 
        def local_hog(X):
            return hog(X)
 
        try: # parallel
            return np.array([local_hog(img) for img in X])
        except:
            return np.array([local_hog(img) for img in X])

# %%
from sklearn.linear_model import SGDClassifier
from sklearn.model_selection import cross_val_predict
from sklearn.preprocessing import StandardScaler, Normalizer
import skimage
 
# create an instance of each transformer
grayify = RGB2GrayTransformer()
hogify = HogTransformer()
scalify = StandardScaler()
 
# call fit_transform on each transform converting X_train step by step
X_train_gray = grayify.fit_transform(X_train)
X_train_hog = hogify.fit_transform(X_train_gray)
X_train_prepared = scalify.fit_transform(X_train_hog)
 
print(X_train_prepared.shape)
# Out:
# (572, 5184)

# %% [markdown]
# ## 2. PCA [10pts]
# 추출한 HoG feature는 5,184 차원을 갖고 있어 주어진 데이터에 비해 너무 큰 차원이다. PCA를 이용하여 차원을 줄이고자 한다. PCA를 이용하여 차원으로 축소하시오. **차원의 개수는 자유롭게 선택하시되 구현할 모델의 성능이 최대가 될 수 있도록 고르는 것을 추천합니다.**

# %%
from sklearn.decomposition import PCA

####################

X_train_pca = ##################

# %% [markdown]
# ## 3. Classification [30pts]
# 수업 시간에 다룬 다양한 classifier (SVM, kNN, LR, deicision tree 등)중 하나를 사용하여 모델을 학습하라.
#
# 정확도 기준,
# - 90 % 성능 이상은 30점
# - 85 ~ 89.9 %은 20점
# - 80 ~ 85 %이하는 10점
# - 80 %이하는 5점
# - 미완성 및 에러 발생 시 0점

# %%
# import any classifer you want


model = ##########################

model.fit(#######################)

# %% [markdown]
# ## Evaluation

# %% [markdown]
# Test set에 대해 분류하고 평가하기

# %%
X_test_gray = grayify.transform(X_test)
X_test_hog = hogify.transform(X_test_gray)
X_test_prepared = scalify.transform(X_test_hog)
X_test_pca = pca.transform(X_test_prepared)

# %%
y_pred = model.predict(X_test_pca)
print(np.array(y_pred == y_test)[:25])
print('')
print('Percentage correct: ', 100*np.sum(y_pred == y_test)/len(y_test))
# Out:
# [False  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#  False]
#
# Percentage correct:  91.66666666666667

# %%
import pandas
import seaborn as sns
from sklearn.metrics import confusion_matrix, classification_report
 
labels = np.unique(y_test)
cmx = confusion_matrix(y_test, y_pred, labels=labels)
sns.heatmap(cmx, fmt='', cmap='Blues')

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#         Bear       0.68      0.85      0.76        20
#      Chicken       0.84      0.91      0.87        23
#         Deer       1.00      1.00      1.00        25
#        Eagle       0.77      0.83      0.80        12
#     Elephant       0.86      0.95      0.90        20
#       Monkey       0.80      0.40      0.53        20
#        Panda       0.96      0.96      0.96        24
#
#     accuracy                           0.85       144
#    macro avg       0.84      0.84      0.83       144
# weighted avg       0.86      0.85      0.84       144
